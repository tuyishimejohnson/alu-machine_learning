# %%
#!/usr/bin/env python3
import numpy as np
import matplotlib.pyplot as plt

mean = [69, 0]
cov = [[15, 8], [8, 15]]
np.random.seed(5)
x, y = np.random.multivariate_normal(mean, cov, 2000).T
y += 180


plt.scatter(x, y, color="magenta")  # This line creates the scatter plot
plt.xlabel("Height (in)") # This line shows Men's height on x-axis
plt.ylabel("Weight (lbs)") # This line shows Men's weight on y-axis
plt.title("Men's Height vs Weight") # The title
plt.show()

# %%
#!/usr/bin/env python3
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 28651, 5730)
r = np.log(0.5)
t = 5730
y = np.exp((r / t) * x)

# your code here

plt.xlabel("Time (years)") # This line shows time in yeaars on x-axis
plt.ylabel("Fraction Remaining") # This line shows fraction remaining on y-axis
plt.title("Exponential Decay of C-14") # The title
plt.semilogy(x,y) # Plots x and y
plt.show()

# %%
#!/usr/bin/env python3
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 21000, 1000)
r = np.log(0.5)
t1 = 5730
t2 = 1600
y1 = np.exp((r / t1) * x)
y2 = np.exp((r / t2) * x)

plt.xlabel("Time (years)") # This line shows time in yeaars on x-axis
plt.ylabel("Fraction Remaining") # This line shows fraction remaining on y-axis
plt.title("Exponential Decay of Radioactive Elements") # The title
plt.plot(x,y1, label="C-14",linestyle="dashed",color="red") #Creating the plot for C-14
plt.plot(x,y2,label="Ra-226", color="green") #Creating the plot for Ra-226
plt.legend() # it adds the legend
plt.show() # displays the plot

# %%
#!/usr/bin/env python3
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(5)
student_grades = np.random.normal(68, 15, 50)

plt.xlabel("Grades")
plt.ylabel("Number of Students")
plt.title("Project A")
plt.hist(student_grades,bins=10, color="#598dc9",edgecolor="black")

plt.show()

# %%
#!/usr/bin/env python3
import numpy as np
import matplotlib.pyplot as plt
SMALL_SIZE = 8
plt.rc('font', size=SMALL_SIZE)
plt.title("All in One")



plt.subplot(3,2,1)
y = np.arange(0, 10) ** 3
x = np.arange(0, 10)

plt.plot(x, y, color="red")

# End of 0 question

mean = [69, 0]
cov = [[15, 8], [8, 15]]
np.random.seed(5)
x, y = np.random.multivariate_normal(mean, cov, 2000).T
y += 180

plt.subplot(3,2,2)
plt.scatter(x, y, color="magenta")  # This line creates the scatter plot
plt.xlabel("Height (in)") # This line shows Men's height on x-axis
plt.ylabel("Weight (lbs)") # This line shows Men's weight on y-axis
plt.title("Men's Height vs Weight") # The title

# End of 1 question



x = np.arange(0, 28651, 5730)
r = np.log(0.5)
t = 5730
y = np.exp((r / t) * x)

plt.subplot(3,2,3)
plt.xlabel("Time (years)") # This line shows time in yeaars on x-axis
plt.ylabel("Fraction Remaining") # This line shows fraction remaining on y-axis
plt.title("Exponential Decay of C-14") # The title
plt.semilogy(x,y) # Plots  x and y with a straight line

# End of 2 question

x = np.arange(0, 21000, 1000)
r = np.log(0.5)
t1 = 5730
t2 = 1600
y1 = np.exp((r / t1) * x)
y2 = np.exp((r / t2) * x)


plt.subplot(3,2,4)
plt.xlabel("Time (years)") # This line shows time in yeaars on x-axis
plt.ylabel("Fraction Remaining") # This line shows fraction remaining on y-axis
plt.title("Exponential Decay of Radioactive Elements") # The title
plt.plot(x,y1, label="C-14",linestyle="dashed",color="red") #Creating the plot for C-14
plt.plot(x,y2,label="Ra-226", color="green") #Creating the plot for Ra-226
plt.legend() # it adds the legend

# End of 3 question


np.random.seed(5)
student_grades = np.random.normal(68, 15, 50)

plt.subplot(3,2,5)
plt.xlabel("Grades")
plt.ylabel("Number of Students")
plt.title("Project A")
plt.hist(student_grades,bins=10, color="#598dc9",edgecolor="black")


# End of 5 question
# Out:
# (array([ 2.,  5.,  4., 14., 10.,  5.,  4.,  4.,  1.,  1.]),
#  array([ 43.02817206,  49.17151163,  55.31485121,  61.45819078,
#          67.60153036,  73.74486993,  79.88820951,  86.03154908,
#          92.17488866,  98.31822823, 104.46156781]),
#  <BarContainer object of 10 artists>)
